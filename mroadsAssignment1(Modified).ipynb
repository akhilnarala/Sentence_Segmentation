# %%
from urllib.request import urlopen
from nltk import sent_tokenize
from bs4 import BeautifulSoup

url ="https://mroads.com/about-us"
html = urlopen(url).read()
soup = BeautifulSoup(html,"html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())

# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))

# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk) 

#Segmentation of sentences  
print("\n".join(sent_tokenize(text)))
# Out:
# About mroads – Innovative HR Products and Services
# HOME
# SEE A DEMO
# COMPANY   +
# About us
# Press
# Blogs
# Careers
# Clients
# Contact us
# PRODUCT
# SERVICES
# About-us mroads
# Who we are and what we do
# mroads is focused on building next generation workforce that leverages technology and awareness.
# We believe innovation leads to generating solutions that make the day to day life easy for humans and organizations.
# We help clients in solving their toughest problems by delivering a globally consistent set of multidisciplinary services.
# We would like to build an organization with people who choose to be happy and influence our customers and co-workers.
# Our goal is to deliver a cutting edge hiring platform that aims to revolutionize the hiring practice and empower HR.
# Everyone here at mroads share ideas fearlessly and out of the box thinking to simplify technologies to deliver innovative products and solutions.
# Out of the box thinking, approaching a solution by immersing yourself into the problem domain and being aware of the current trends help in building innovative solutions.
# An organization should be measured by the happiness index of its employees.
# If we can move this one needle, it will forge our path to success.
# Technology is going through a change of leaps and bounds in the past decade.
# The world has moved from desktop computing to the ever accessible cloud based computing.
# Access to solutions/data has taken revolutionary path with wireless access and being connected from anywhere.
# These changes have great impact on how we build innovative products.
# Our Products contribute to the on-going technology revolution.
# In the end, it is the journey that matters and not the destination.
# In this journey, we adhere to values that lead us through balanced approach in work and life.
# Meet the board
# Manohar Kesireddy President & CEO At mroads, Manohar is responsible for day-to-day operations as well as leading the company's product development and technology strategy.
# He has over 15 years of experience in corporate at various roles and holds several patents in technology.
# He has successfully led development teams at Verizon Telecom.
# Manohar holds a bachelor's degree from IIT Madras, India and a Master's degree in computer science from University of Texas at Dallas.
# He is also a member of board for the non-profit organization India Dreams.
# In his spare time, Manohar practices Vipassana meditation and is working hard to make par scores in golf!
# Prakash Nallagatla
# Co-Founder/Vice-President Prakash heads the development effort at mroads and is responsible for product planning and development, engineering, deployment and service assurance for mroads products.
# With over 18 years of experience, Prakash has held various management positions, managing large diverse teams and overseeing high-risk projects.
# He began his career at Nortel Networks developing automation build tools for their software and moved on to GTE/Verizon where he held various leadership roles while developing cutting edge products.
# He is a recipient of various excellence awards at Verizon and also holds a technology patent.
# Prakash has a Master's Degree in Computer Science from University of Texas at Dallas.
# In his spare time, Prakash avidly follows professional leagues of basketball, football and enjoys playing a round of golf.
# He is also very passionate about electronics and gadgets that impact human life as we know today.
# Rahul Kukreti Co-Founder/Chief Marketing Officer As a chief marketing officer, Rahul oversees the entire marketing and sales effort for mroads and it’s products.
# Rahul is vital contributor to the mroads leadership team.
# Backed by 16 years of experience in various roles in sales and marketing, Rahul is responsible for attracting new clients while retaining existing ones.
# Formerly, Rahul worked with HP, KPMG and Nortel Networks, leading organizational strategies, promoting operational effectiveness and elevating team performances.
# He was instrumental in building strategic relationships and creating new revenue streams, just as he currently does at mroads.
# In his spare time, Rahul plays the game of cricket and has had the honor of representing United States as a captain for the national team.
# He is very passionate about what he does and challenges himself constantly to make a difference in the world.
# We are looking for that next superstar to be a part of our team.Interested?
# Job Openings
# AMERICAS 5550 Granite Pkwy Suite #225Plano, Texas 75024972 752 3418reachout@mroads.com
# 300 E Royal Lane, Suite 111 Irving, Texas 75039972 752 3418reachout@mroads.com
# INDIACyber Gateway, Block-C Hitec City, Hyderabad, Telangana, India.040-40555060reachout@mroads.com
# © Copyright 2017. mroads.
# All rights reserved.
# Follow us

# %%
from urllib.request import urlopen
from nltk import sent_tokenize
from bs4 import BeautifulSoup

url ="http://www.vnrvjiet.ac.in/history.php"
html = urlopen(url).read()
soup = BeautifulSoup(html,"html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())

# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))

# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk) 

#Segmentation of sentences  
print("\n".join(sent_tokenize(text)))
# Out:
# VNR:History
# Toggle navigation
# Home
# About Us
# History
# Objectives
# Founders
# Governing Council
# Principal
# Academics
# Admissions
# Departments
# Civil Engineering
# Electrical & Electronics Engineering
# Mechanical Engineering
# Electronics & Communication Engineering
# Computer Science & Engineering
# Electronics & Instrumentation Engineering
# Information Technology
# Automobile Engineering
# Humanities and Sciences
# Research
# Sections
# Examinations & Evaluation
# Sports
# Administrative Office
# ED Cell
# IIPC Cell
# PAAC Cell
# Hostels
# NSS Report
# IQAC
# Training & Placement
# Vision
# Students Placed
# Gallery
# Open House
# Sports Day
# Convergence
# Annual Day
# Cultural Day
# Contact Us
# Latest News
# NIRF Put VNRVJIET In 101-150 Rank Band all over India
# 882 students have been placed for the academic year 2016-2017.
# History
# Funded entirely by educationalists, industrialists, businessmen and individuals, VIGNANA JYOTHI SOCIETY was conceived in the year 1990
# as a not-for-profit organization.
# Education is the backbone of a society's growth and development.
# It was therefore felt that maximum contribution
# to society can be made in this sphere.
# The members of Vignana Jyothi Society are eminent and successful people with a common desire to serve the
# community through value based education.
# It is the Philosophy of Vignana Jyothi that education is a process of "Presenting" that provides, both individually and collectively, to one's deepest
# capacity to sense and shape the future.
# Based on a synthesis of direct experience, leading edge thinking and ancient wisdom, it taps into 'deeper levels
# of LEARNING for discovering new possibilities'.
# Today with this philosophy, Vignana Jyothi has created an edifice with unshakable foundations which can only grow higher and higher.
# Conscious of
# quality and integrity in everything they undertake and achieving EXCELLENCE as a habit, Institutions run by VignanaJyothi reflect their character,
# vision and passion for education.
# In the year 1995, Vignana Jyothi started the Vallurupalli Nageswara Rao Vignana Jyothi Institute of Engineering &Technology;(VNR VJIET), named after
# one of the donors and Vice Presidents of the Vignana Jyothi at Bachupally, VNRVJIET with affiliation to
# Jawahar Nehru Technological University(JNTUH), Hyderabad was established with the permission of
# The All India Council for Technical Education (AICTE), New Delhi and Government of Andhra Pradesh.
# The Institute was accorded Autonomous status for SIX years by University Grants Commission( UGC ) from the year 2012.
# The institute is NAAC accredited with "A" Grade under autonomous status.
# A distinct and fresh perspective worked out by VIGNANA JYOTHI Society make VNRVJIET(VJ)different and exclusive to join the top ranking Institutions
# across India.
# The Management of VNRVJIET believes that by being research driven, by providing world class infrastructure and by adapting a strategic
# and practical approach towards teaching that is aided by an experienced faculty, the institute differentiates itself from other institutions and joins
# the band of EXCLUSIVE AND PREFERRED INSTITUTIONS providing a value-sensitive workforce and leaders of tomorrow.
# HEAD OFFICE
# Vignana Jyothi Group of Institutions
# H.No.7-1-4, Begumpet
# Hyderabad-500 016
# Phone:040-23731555
# Contact
# Vignana Jyothi Nagar,Pragathi Nagar,
# Nizampet(S.O),Hyderabad 500 090
# TS,India.
# Telephone No: 91-040-23042758 /59/60,
# Fax: 91-040-23042761.
# Email:postbox@vnrvjiet.ac.in,
# Website:www.vnrvjiet.ac.in
# Copyright © 2017
# Developed By VNRVJIET
